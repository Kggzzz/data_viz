# %% [markdown]
# <a href="https://colab.research.google.com/github/Kggzzz/data_viz/blob/main/MyNote.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Pandas
#
# คำสั่งแพนด้าต่างๆ เผื่อไม่เข้าใจ แต่ก็ไม่รู้เข้าใจมั้ย

# %% [markdown]
# ```.read_csv('ชื่อไฟล์.csv')```
#
# คำสั่งอ่านไฟล์ CSV

# %% [markdown]
# ```.head('จำนวน row ที่อยากได้ออกมาแสดงนับจากแถวบนสุด')```
#
# ดูหัวตาราง หรือหัวแถวตามจำนวนที่ต้องการได้
#
# ```.tail('จำนวน row ที่อยากได้ออกมาแสดงนับจากแถวล่างสุด')```
#
# ดูท้ายตาราง หรือท้ายแถวตามจำนวนที่ต้องการได้
#
# ```.sample('จำนวนของแถวข้อมูลที่ต้องการ')```
#
# เป็นการเรียกดูข้อมูลแบบสุ่ม

# %% [markdown]
# ```.info()```
#
# เรียกดูความผิดปกติของ DataFrame นั้นๆ  เช่น
#
# ![image.png](data:image/png;base64,...)
#
# สิ่งที่ออกมาจะเป็นจำนวน column และ จำนวน row ของข้อมูล รวมถึงหัวข้อ column และชนิดของข้อมูลนั้นๆ

# %% [markdown]
# ```.astype('ชนิดของข้อมูลที่ต้องการ')```
#
# การแปลงชนิดของข้อมูลตามที่ต้องการ
#
# เช่น ข้อมูลนี้
#
# ![image.png](data:image/png;base64,...)
#
# ทำการเปลี่ยนชนิดตัวแปร
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```.describe()```
#
# เป็นการหาค่า (count, mean ,std ,min ,25% ,50% ,75%, max)ของข้อมูลแต่ละ column
# ตัวอย่างสามารถดูได้ใน pandas102 แต่ยังติดปัญหาการเรียก Min Max
#
# ตัวอย่าง
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```.Categorical()```
#
# เป็นการจัดกลุ่มให้กับข้อมูลของเรา (น่าจะไม่ได้ใช้เท่าไหร่)
#
# ตัวอย่าง
#
# ![image.png](data:image/png;base64,...)
#
# จากคำสั่งนี้จะเห็นได้ว่าทำ ผลลัพท์ categories จะมีแค่ 5 ตัว เท่าได้นั้นแก่ [e,f,h,i,m] สาเหตุเพราะ categories นั้นจะไม่นับตัวซ้ำว่าเป็นอีก 1 categories นอกจากนี้เรายังสามารถกำหนดข้อมูลใน categories อีกทีได้ด้วยการเพิ่มตัวแปร categories พร้อมตัวด้วยค่า categories ที่ต้องการลงไปจะได้ผลลัพท์ดังภาพ
#
# ![image.png](data:image/png;base64,...)
#
# จากผลลัพท์ จะเห็นได้ว่า categories ที่กำหนดให้มีแค่ [‘e’,’m’,’f’] ดังนั้นข้อมูล i กับ h เมื่อแสดงผลจึงเป็น NaN

# %% [markdown]
# ####ค่าวันที่และเวลา (น่าจะยังไม่ได้ใช้เพราะค่าข้อมูลในข้อสอบเป็นตาราง)
#
# ```.date_range()```
#
# โดย date_range นั้นมีความสามารถที่ทำให้เราสามารถเพิ่มค่าเองได้ตั้งแต่หน่วยเวลา ไปจนถึงหน่วยวัน พร้อมกับกำหนด timezone เองได้ด้วยเช่นกัน
#
# ```.date_range(start,end,freq)```
#
# ตัวอย่างทำการสร้างค่าวันที่และเวลาโดยกำหนดให้เริ่มตั้งแต่วัน ที่ 1–1–2018 ถึงวันที่ 1–05–2018 โดยเพิ่มขึ้นทุกๆ 5 ชม
#
# ![image.png](data:image/png;base64,...)
#
#
# ```.date_range(start,end,period)```
#
# ทำการสร้างค่าวันที่และเวลาโดยกำหนดให้เริ่มตั้งแต่วัน ที่ 1–1–2018 ถึงวันที่ 30–01–2018 โดยแบ่งออกเป็น 3 ช่วง
#
# ![image.png](data:image/png;base64,...)
#
#
# ```.date_range(start,end,period,tz)```
#
# ทำการสร้างค่าวันที่และเวลาโดยกำหนดให้เริ่มตั้งแต่วัน ที่ 1–1–2018 โดยแบ่งออกเป็น 5 ช่วง
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####การสร้าง DataFrame
#
# ```.DataFrame(ตัวแปร dict)```
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```variable[‘ชื่อcolumn1’, ‘ชื่อcolumn2’, ชื่อcolumn3']```
#
# เป็น column ที่เราต้องการ
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####วิธีการเช็คข้อมูล
#
# ```.isnull()```
#
# วิธีเช็คข้อมูล ที่เป็น Null
#
#
# ```.notnull()```
#
# วิธีเช็คข้อมูล ที่ไม่เป็นเป็น Null

# %% [markdown]
# ####การกรองข้อมูล
#
# ```.query(‘เงื่อนไขที่ต้องการ’)```
#
# กรองข้อมูลแบบมีเงื่อนไข
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```.agg()```
#
# การหาค่า mean, max , sum (aggregate)ทั้ง dataframe
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```.unique()```
#
# การหาค่าข้อมูลที่ไม่ซ้ำกันในแต่ละ column
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```.duplicated()```
#
# การหาข้อมูลที่ซ้ำในตาราง
#
# ![image.png](data:image/png;base64,...)
#
# จากภาพจะสังเกตุว่า row ชื่อ cobra แจ้งเป็น False ทั้งๆที่มีค่าซ้ำกับ row ชื่อ viper สาเหตุเป็นเพราะว่า คำสั่ง duplicated จะไม่มองตัวแรกที่เจอว่าเป็นข้อมูลซ้ำ

# %% [markdown]
# เราสามารถนับข้อมูลที่ซ้ำได้อีกด้วยโดยใช้ ```len(dataframe[dataframe.duplicated([‘column name’], keep = False)])```
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###การแทนค่าข้อมูลในตาราง
#
# ```.replace()```
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #สูตร Z-score
#
# ![image.png](data:image/png;base64,...)
