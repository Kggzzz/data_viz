# %% [markdown]
# <a href="https://colab.research.google.com/github/Kggzzz/data_viz/blob/main/Quiz03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
path = '/content/drive/My Drive/Data_viz'
os.listdir(path)
# Out:
# ['covid-19-daily_data_dictionary.xlsx',
#  'pm-18-jan-2021.csv',
#  '18-jan-2021.xlsx',
#  'pm-24-jan-2021.csv',
#  'Project1-StuList-1-63-ตัดเกรด_renamed.xlsx',
#  'คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',
#  'คะแนนสอบปากเปล่าของกรรมการสอบ_renamed.xlsx',
#  '3.-41-58.csv',
#  '3.-41-58.xls',
#  '-.57-.58-1.xls']

# %%
_file_path = os.path.join(path,'-.57-.58-1.xls')
print(sale_file_path)
# Out:
# /content/drive/My Drive/Data_viz/-.57-.58-1.xls

# %%
sale_df= pd.read_excel(sale_file_path,sheet_name=0,skiprows=0,header=4)
sale_df
# Out:
#    ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 0    ที่  ...                      NaN
# 1      1  ...           เป็นผู้รับจ้าง
# 2      2  ...           เป็นผู้รับจ้าง
# 3      3  ...           เป็นผู้รับจ้าง
# 4      4  ...           เป็นผู้รับจ้าง
# ..   ...  ...                      ...
# 95    56  ...           เป็นผู้รับจ้าง
# 96    57  ...           เป็นผู้รับจ้าง
# 97    58  ...           เป็นผู้รับจ้าง
# 98    59  ...           เป็นผู้รับจ้าง
# 99    60  ...           เป็นผู้รับจ้าง
#
# [100 rows x 9 columns]

# %%
sale = pd.read_excel(sale_file_path,sheet_name=1,skiprows=0,header=4)
sale
# Out:
#                                                 ลำดับ  ...  เหตุผลที่คัดเลือกโดยสรุป
# 0                                                 ที่  ...                       NaN
# 1                                                   1  ...            เป็นผู้รับจ้าง
# 2                                                   2  ...            เป็นผู้รับจ้าง
# 3                                                   3  ...            เป็นผู้รับจ้าง
# 4                                                   4  ...            เป็นผู้รับจ้าง
# 5                                                   5  ...            เป็นผู้รับจ้าง
# 6                                                   6  ...            เป็นผู้รับจ้าง
# 7                                                   7  ...            เป็นผู้รับจ้าง
# 8                                                   8  ...            เป็นผู้รับจ้าง
# 9                                                   9  ...            เป็นผู้รับจ้าง
# ...

# %%
oct57 = pd.read_excel('จัดซื้อ 57-58.xls', sheet_name=0,header=4, skipfooter=20) #utf-8 -- latin1
oct57 = oct57.dropna()
oct57

# %%
oct57 = oct57.rename(columns={'Unnamed: 5' : 'ราคาเสนอ', 'Unnamed: 7': 'ราคาซื้อ'})
oct57

# %%
nov57 = pd.read_excel('จัดซื้อ 57-58.xls', sheet_name=0,header=4, skipfooter=20) #utf-8 -- latin1
oct57 = oct57.dropna()
oct57
