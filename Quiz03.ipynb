# %% [markdown]
# <a href="https://colab.research.google.com/github/Kggzzz/data_viz/blob/main/Quiz03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
path = '/content/drive/My Drive/Data_viz'
os.listdir(path)
# Out:
# ['covid-19-daily_data_dictionary.xlsx',
#  'pm-18-jan-2021.csv',
#  '18-jan-2021.xlsx',
#  'pm-24-jan-2021.csv',
#  'Project1-StuList-1-63-ตัดเกรด_renamed.xlsx',
#  'คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',
#  'คะแนนสอบปากเปล่าของกรรมการสอบ_renamed.xlsx',
#  '3.-41-58.csv',
#  '3.-41-58.xls',
#  '-.57-.58-1.xls']

# %%
sale_file_path = os.path.join(path,'-.57-.58-1.xls')
print(sale_file_path)
# Out:
# /content/drive/My Drive/Data_viz/-.57-.58-1.xls

# %%
sale = pd.read_excel(sale_file_path,sheet_name=0,skiprows=0,header=4)
sale
# Out:
#    ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 0    ที่  ...                      NaN
# 1      1  ...           เป็นผู้รับจ้าง
# 2      2  ...           เป็นผู้รับจ้าง
# 3      3  ...           เป็นผู้รับจ้าง
# 4      4  ...           เป็นผู้รับจ้าง
# ..   ...  ...                      ...
# 95    56  ...           เป็นผู้รับจ้าง
# 96    57  ...           เป็นผู้รับจ้าง
# 97    58  ...           เป็นผู้รับจ้าง
# 98    59  ...           เป็นผู้รับจ้าง
# 99    60  ...           เป็นผู้รับจ้าง
#
# [100 rows x 9 columns]

# %%
sale2 = pd.read_excel(sale_file_path,sheet_name=1,skiprows=0,header=4)
sale2
# Out:
#                                                 ลำดับ  ...  เหตุผลที่คัดเลือกโดยสรุป
# 0                                                 ที่  ...                       NaN
# 1                                                   1  ...            เป็นผู้รับจ้าง
# 2                                                   2  ...            เป็นผู้รับจ้าง
# 3                                                   3  ...            เป็นผู้รับจ้าง
# 4                                                   4  ...            เป็นผู้รับจ้าง
# 5                                                   5  ...            เป็นผู้รับจ้าง
# 6                                                   6  ...            เป็นผู้รับจ้าง
# 7                                                   7  ...            เป็นผู้รับจ้าง
# 8                                                   8  ...            เป็นผู้รับจ้าง
# 9                                                   9  ...            เป็นผู้รับจ้าง
# ...

# %% [markdown]
# #HW 8

# %%
sale_df = pd.read_excel(sale_file_path,sheet_name=0,skiprows=0,header=20)
sale_df.head(10)
# Out:
#                                                 15  ...            เป็นผู้รับจ้าง
# 0                                              NaN  ...                แบบ สขร. 1
# 1  สรุปผลการดำเนินการจัดจ้างในรอบเดือน ตุลาคม 2557  ...                       NaN
# 2       สำนักงานปลัดกระทรวงวิทยาศาสตร์และเทคโนโลยี  ...                       NaN
# 3                                              NaN  ...                       NaN
# 4                                            ลำดับ  ...  เหตุผลที่คัดเลือกโดยสรุป
# 5                                              ที่  ...                       NaN
# 6                                               16  ...            เป็นผู้รับจ้าง
# 7                                               17  ...            เป็นผู้รับจ้าง
# 8                                               18  ...            เป็นผู้รับจ้าง
# 9                                               19  ...            เป็นผู้รับจ้าง
#
# [10 rows x 9 columns]

# %%
sale_df = sale_df.dropna()
sale_df
# Out:
#     15  ...  เป็นผู้รับจ้าง
# 6   16  ...  เป็นผู้รับจ้าง
# 7   17  ...  เป็นผู้รับจ้าง
# 8   18  ...  เป็นผู้รับจ้าง
# 9   19  ...  เป็นผู้รับจ้าง
# 10  20  ...  เป็นผู้รับจ้าง
# 11  21  ...  เป็นผู้รับจ้าง
# 12  22  ...  เป็นผู้รับจ้าง
# 13  23  ...  เป็นผู้รับจ้าง
# 14  24  ...  เป็นผู้รับจ้าง
# 15  25  ...  เป็นผู้รับจ้าง
# 16  26  ...  เป็นผู้รับจ้าง
# 17  27  ...  เป็นผู้รับจ้าง
# 18  28  ...  เป็นผู้รับจ้าง
# 19  29  ...  เป็นผู้รับจ้าง
# 20  30  ...  เป็นผู้รับจ้าง
# 27  31  ...  เป็นผู้รับจ้าง
# 28  32  ...  เป็นผู้รับจ้าง
# 29  33  ...  เป็นผู้รับจ้าง
# 30  34  ...  เป็นผู้รับจ้าง
# 31  35  ...  เป็นผู้รับจ้าง
# 32  36  ...  เป็นผู้รับจ้าง
# 33  37  ...  เป็นผู้รับจ้าง
# 34  38  ...  เป็นผู้รับจ้าง
# 35  39  ...  เป็นผู้รับจ้าง
# 36  40  ...  เป็นผู้รับจ้าง
# 37  41  ...  เป็นผู้รับจ้าง
# 38  42  ...  เป็นผู้รับจ้าง
# 39  43  ...  เป็นผู้รับจ้าง
# 40  44  ...  เป็นผู้รับจ้าง
# 41  45  ...  เป็นผู้รับจ้าง
# 48  31  ...  เป็นผู้รับจ้าง
# 49  32  ...  เป็นผู้รับจ้าง
# ...

# %%
sale_df = sale_df.rename(columns={'Unnamed: 5' : 'ราคาเสนอ', 'Unnamed: 7': 'ราคาซื้อ'})
sale_df
# Out:
#     15  ...  เป็นผู้รับจ้าง
# 6   16  ...  เป็นผู้รับจ้าง
# 7   17  ...  เป็นผู้รับจ้าง
# 8   18  ...  เป็นผู้รับจ้าง
# 9   19  ...  เป็นผู้รับจ้าง
# 10  20  ...  เป็นผู้รับจ้าง
# 11  21  ...  เป็นผู้รับจ้าง
# 12  22  ...  เป็นผู้รับจ้าง
# 13  23  ...  เป็นผู้รับจ้าง
# 14  24  ...  เป็นผู้รับจ้าง
# 15  25  ...  เป็นผู้รับจ้าง
# 16  26  ...  เป็นผู้รับจ้าง
# 17  27  ...  เป็นผู้รับจ้าง
# 18  28  ...  เป็นผู้รับจ้าง
# 19  29  ...  เป็นผู้รับจ้าง
# 20  30  ...  เป็นผู้รับจ้าง
# 27  31  ...  เป็นผู้รับจ้าง
# 28  32  ...  เป็นผู้รับจ้าง
# 29  33  ...  เป็นผู้รับจ้าง
# 30  34  ...  เป็นผู้รับจ้าง
# 31  35  ...  เป็นผู้รับจ้าง
# 32  36  ...  เป็นผู้รับจ้าง
# 33  37  ...  เป็นผู้รับจ้าง
# 34  38  ...  เป็นผู้รับจ้าง
# 35  39  ...  เป็นผู้รับจ้าง
# 36  40  ...  เป็นผู้รับจ้าง
# 37  41  ...  เป็นผู้รับจ้าง
# 38  42  ...  เป็นผู้รับจ้าง
# 39  43  ...  เป็นผู้รับจ้าง
# 40  44  ...  เป็นผู้รับจ้าง
# 41  45  ...  เป็นผู้รับจ้าง
# 48  31  ...  เป็นผู้รับจ้าง
# 49  32  ...  เป็นผู้รับจ้าง
# ...

# %%
data_df_2 = pd.read_excel(sale_file_path,sheet_name='พย.57',header=4,skipfooter=30)
data_df_2
# Out:
#   ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 0   ที่  ...                      NaN
# 1     1  ...           เป็นผู้รับจ้าง
# 2     2  ...           เป็นผู้รับจ้าง
# 3     3  ...           เป็นผู้รับจ้าง
# 4     4  ...           เป็นผู้รับจ้าง
# 5     5  ...           เป็นผู้รับจ้าง
# 6     6  ...           เป็นผู้รับจ้าง
#
# [7 rows x 9 columns]

# %%
sale_df2 = pd.read_excel(sale_file_path,sheet_name='พย.57',header=4,skipfooter=30) #utf-8 -- latin1
sale_df2 = sale_df2.dropna()
sale_df2
# Out:
#   ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 1     1  ...           เป็นผู้รับจ้าง
# 2     2  ...           เป็นผู้รับจ้าง
# 3     3  ...           เป็นผู้รับจ้าง
# 4     4  ...           เป็นผู้รับจ้าง
#
# [4 rows x 9 columns]

# %%
#นำตารางดาต้ามาต่อกัน 
data_concat = pd.concat([sale_df,sale_df2])
data_concat
# Out:
#      15  ... เหตุผลที่คัดเลือกโดยสรุป
# 6    16  ...                      NaN
# 7    17  ...                      NaN
# 8    18  ...                      NaN
# 9    19  ...                      NaN
# 10   20  ...                      NaN
# ..  ...  ...                      ...
# 82   59  ...                      NaN
# 1   NaN  ...           เป็นผู้รับจ้าง
# 2   NaN  ...           เป็นผู้รับจ้าง
# 3   NaN  ...           เป็นผู้รับจ้าง
# 4   NaN  ...           เป็นผู้รับจ้าง
#
# [63 rows x 18 columns]

# %%
data = data_concat.rename(columns={'Unnamed: 5':'ราคาเสรอ','Unnamed: 7':'ราคาาซื้อ'})
data
# Out:
#      15  ... เหตุผลที่คัดเลือกโดยสรุป
# 6    16  ...                      NaN
# 7    17  ...                      NaN
# 8    18  ...                      NaN
# 9    19  ...                      NaN
# 10   20  ...                      NaN
# ..  ...  ...                      ...
# 82   59  ...                      NaN
# 1   NaN  ...           เป็นผู้รับจ้าง
# 2   NaN  ...           เป็นผู้รับจ้าง
# 3   NaN  ...           เป็นผู้รับจ้าง
# 4   NaN  ...           เป็นผู้รับจ้าง
#
# [63 rows x 18 columns]
